# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedHefnawy/PreProcessing_Guide/blob/master/PreProcessing_guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Pre-Proceesing Guide
# _______________

# %% [markdown]
# ## Misiing Values
# * [Take a first look at the data](#Take-a-first-look-at-the-data)
# * [Explore Missing values](#Explor-Nan-values-count)
# * [Visualze, Figure out why the data is missing](#Figure-out-why-the-data-is-missing)
# * [Handel Mising Values](#Handel-Mising-Values)
# > * [Drop misiing values](#Drop-missing-values)
# > * [Filling in missing values](#Filling-in-missing-values)
# * [Liberaries Needed in missing values](#Liberaries-Needed)

# %% [markdown]
# ## Data Transforms
# * [Rescale data](#Rescale-data)
# * [Standardize data](#Standardize-Data)
# * [Normalize data](#Normalization)
# * [Binarize data](#Binarize-Data)

# %% [markdown]
# ## Outliers
# * [Methods to detect outliers ](#Outliers-Handling)
# * [Methods to Pre-Process Outliers](#Methods-to-Pre-Process-Outliers)

# %% [markdown]
# ## Handle duplicate records
# * [Finding and Droping Duplicate records](#Duplicate-records)

# %% [markdown]
# ___________________________

# %% [markdown]
# ### Take a first look at the data

# %% [markdown]
# - load libraries and datasets
# - show Sample to know it's all readed done and successfully

# %% [markdown]
# # [Missing Values](#)
#
# #### **Explor Nan values count**
# df.isna().sum()

# %% [markdown]
# ______
# ### Figure out why the data is missing
# #### *There's no statistical way to determine if you data is missing at random or not. This is one of those cases where the solution is just to spend some time getting to know your data and how it was generated.*
# ### Look to the missing values
# #### **The fact that the value is missing tells us something about the value.**
# > ##### it's just missing at random because someone forgot to write it down or something. So you can Think to fill it Using some techniques.
# > ##### or it missing intentionaly, It's probably missing because it doesn't have a value ** and you have to think deeply in your data here.**

# %% [markdown]
# ____________
# ### Visualize your missing data

# %% [markdown]
# > It can be a frustrating part of data science, especially if you're newer to the field and don't have a lot of experience. For dealing with missing values, you'll need to use your intution to figure out why the value is missing. One of the most important question you can ask yourself to help figure this out is this:
#
# - >Is this value missing becuase it wasn't recorded or becuase it dosen't exist?
#
# > If a value is missing becuase it doens't exist (like the height of the oldest child of someone who doesn't have any children) then it doesn't make sense to try and guess what it might be. These values you probalby do want to keep as NaN.
#
# > if a value is missing becuase it wasn't recorded, then you can try to guess what it might have been based on the other values in that column and row. (This is called "imputation" that meamn : > **Imputation**: The fancy math term for guessing what the value of a missing cell in your dataset should actually be.  )

# %% [markdown]
# > --=> 1) Matrix :
#
# > __ __ _ __ _ __ import missingno as msno
#
# > __ __ _ __ _ __ msno.matrix(DataSet)

# %% [markdown]
# > --=> 2) Bar plot
#
# > __ __ _ __ _ __ import missingno as msno
#
# > __ __ _ __ _ __ msno.bar(DataSet)

# %% [markdown]
# > --=> 3) Heatmap :
#
# > __ __ _ __ _ __ import missingno as msno
#
# > __ __ _ __ _ __ msno.heatmap(DataSet)

# %% [markdown]
# ___________
# ### now you have to work on your Missing values!
# #### and there ara many ways to deal with it..

# %% [markdown]
# ### [Handel Mising Values](#)

# %%
from IPython.display import Image
Image(filename='F://Careers//Machine Learning//Articls - photos - Cheatsheets//Misiing values.png',width=700,height=100)

# %% [markdown]
# ### Drop missing values

# %% [markdown]
# > --=> Drop missing values in all DataSet
#
# > __ __ _ __ _ __ DataSet.dropna()

# %% [markdown]
# > --=> Drop all columns with at least one missing value
#
# > __ __ _ __ _ __ DataSet..dropna(axis=1)

# %% [markdown]
# > --=> just how much data did we lose?
#
# > __ __ _ __ _ __ print("Columns in original dataset: %d \n" % Original_Data_Set.shape[1])
# > __ __ _ __ _ __ print("Columns with na's dropped: %d" % df.shape[1])

# %% [markdown]
# ### Filling in missing values

# %% [markdown]
# ##### Stratigies > **if MisSing values are missing completely at random**

# %% [markdown]
# - mean or median for numerical variables.
# - mode for categorical variables.
# > > The major limitation of using this method is that it leads to biased estimates of the variances and covariance.

# %% [markdown]
# - Filling in missing values automatically by det. Value
# > Data_set.fillna(X_VALUE)

# %% [markdown]
# - fillin with whatever value comes directly after it in the same column
# > DataSet.fillna(method = 'bfill', axis=0).fillna(0)
# ##### This makes a lot of sense for datasets where the observations have some sort of logical order to them.)

# %% [markdown]
# Code .|||>  Scikit-learn comes with an imputed function in the form
#
# `sklearn.preprocessing.Imputer(missing_values='NaN', strategy='mean', axis=0, verbose=0, copy=True)`.
#
# Strategy is the imputation strategy and the default is the "mean" of the axis (0 for columns and 1 for rows). The other strategies are "median" and "most_frequent". Another API that can be used for this imputation is fancyimpute.SimpleFill().

# %% [markdown]
# - Imputation with Regression
#
# > replace the missing values with predicted values from a regression model.
#
# > The major drawback of using this method is that it reduces variability and overestimates the model fit and correlation coefficient.
#
# > Scikit-learn preprocessing Imputer function can be utilized for this imputation technique.

# %% [markdown]
# - k-Neareast Neighbor (kNN) Imputation
# > NOT WITH LARGE DATA **Time Coplexity**
#
# >fancyimpute.kNN(k=x).complete(data matrix) can be used for kNN imputation.
#
# > Choosing the correct value for the number of neighbors (k) is also an important factor to consider when using kNN imputation.

# %% [markdown]
# - MICE || Multiple Imputation using
# > The MICE algorithm works by running multiple regression models and each missing value is modeled conditionally depending on the observed (non-missing) values.
# > `fancyimpute.MICE().complete(data matrix)` can be used for MICE implementation.

# %% [markdown]
# ### Liberaries Needed

# %%
# import pandas as pd # for filling methods
# import numpy as np # for mathematics functions (mean,median,std,count,sum,,,etc)
# import missingno as msno # Missing value Visualization
# sklearn.preprocessing.Imputer # impute function
# import fancyimpute # For MICE algorithm

# %% [markdown]
# __________
# _____________

# %% [markdown]
# ______

# %% [markdown]
# # [Data Transform](#)
#  A difficulty is that
# different algorithms make different assumptions about your data and may require different
# transforms. Further, when you follow all of the rules and prepare your data, sometimes algorithms
# can deliver better results without pre-processing.

# %% [markdown]
# The main difference between Scalling, Normalize data
# > The difference is that, in **[scaling](#)** , you're changing the range of your data while in **[normalization](#)** you're changing the shape of the distribution of your data.

# %% [markdown]
# #### **Rescale data**
# >
# This means that you're transforming your data so that it fits within a specific scale, like 0-100 or 0-1. You want to scale data when you're using methods based on measures of how far apart data points, like support vector machines, or SVM or k-nearest neighbors, or KNN. With these algorithms, a change of "1" in any numeric feature is given the same importance.
# > can be helpful in cases where the data follows a Gaussian distribution. However, this does not have to be necessarily true. Also, unlike normalization, standardization does not have a bounding range. So, even if you have outliers in your data, they will not be affected by standardization.

# %% [markdown]
# > useful for optimization algorithms used in the core of machine learning algorithms like gradient
# descent. It is also useful for algorithms that weight inputs like
# - regression
# - neural networks
# - k-Nearest Neighbors.: algorithms that use distance measures like

# %% [markdown]
# You can rescale your data
#
# `using scikit-learn using the MinMaxScaler`

# %%
from sklearn.preprocessing import MinMaxScaler # import MinMax Algorithm

array = dataframe.values # Convert your data to Numpy array 

# separate array into input and output components
X = array[:,0:x] # X = All Colums - 1
Y = array[:,x] # Y is the target you need to predict
scaler = MinMaxScaler(feature_range=(0, 1)) # 0 , 1 the range you need to transform Data
rescaledX = scaler.fit_transform(X) # fit your data (X) to the algorithm
# ______________________________________ Done!
# summarize transformed data
set_printoptions(precision=3)
print(rescaledX[0:5,:])

# %% [markdown]
# _____
# ### **Standardize Data**

# %% [markdown]
# > - useful technique to transform attributes with a Gaussian distribution and differing means and standard deviations to a standard Gaussian distribution with a mean of 0 and a standard deviation of 1.
#
# > It is most suitable for techniques that assume a Gaussian
# distribution in the input variables and work better with rescaled data, such as
# - linear regression
# - logistic regression
# - linear discriminate analysis.

# %% [markdown]
# You can standardize data using
#
# `scikit-learn with the StandardScaler`

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler
array = dataframe.values
# separate array into input and output components
X = array[:,0:x]
Y = array[:,x]
scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)
# summarize transformed data
set_printoptions(precision=3)
print(rescaledX[0:5,:])

# %% [markdown]
# ____
# #### **Normalization**
# >in scikit-learn refers to rescaling each observation (row) to have a length of 1 (called
# a unit norm or a vector with the length of 1 in linear algebra).
#
# > Scaling just changes the range of your data. Normalization is a more radical transformation. The point of normalization is to change your observations so that they can be described as a normal distribution.
#
# > > **Normal distribution** : Also known as the "bell curve", this is a specific statistical distribution where a roughly equal observations fall above and below the mean, the mean and the median are the same, and there are more observations closer to the mean. The normal distribution is also known as the Gaussian distribution.
#
# > is good to use when you know that the distribution of your data does not follow a Gaussian distribution. This can be useful in algorithms that do not assume any distribution of the data like K-Nearest Neighbors and Neural Networks.
#
# > you'll only want to normalize your data if you're going to be using a machine learning or statistics technique that assumes your data is normally distributed. Some examples of these include t-tests, ANOVAs, linear regression, linear discriminant analysis (LDA) and Gaussian naive Bayes. (Pro tip: any method with "Gaussian" in the name probably assumes normality.)

# %% [markdown]
# > This pre-processing method can be useful for sparse datasets (lots of zeros) with attributes of varying scales when using
# algorithms that weight input values such as
# - neural networks
# - algorithms that use distance measures such as k-Nearest Neighbors.

# %% [markdown]
# You can normalize data in Python with
#
# `scikit-learn using the Normalizer`

# %%
# Normalize data (length of 1)
from sklearn.preprocessing import Normalizer
from numpy import set_printoptions
array = dataframe.values
# separate array into input and output components
X = array[:,0:x]
Y = array[:,x]
scaler = Normalizer().fit(X)
normalizedX = scaler.transform(X)
# summarize transformed data
set_printoptions(precision=3)
print(normalizedX[0:5,:])

# %% [markdown]
# > Wrap
# - Use MinMaxScaler as the default if you are transforming a feature. It’s non-distorting.
# - You could use RobustScaler if you have outliers and want to reduce their influence. However, you might be better off removing the outliers, instead.
# - Use StandardScaler if you need a relatively normal distribution.
# - Use Normalizer sparingly — it normalizes sample rows, not feature columns. It can use l2 or l1 normalization.

# %% [markdown]
# ___________________________

# %% [markdown]
# ### **Binarize Data**

# %% [markdown]
# > You can transform your data using a binary threshold. All values above the threshold are
# marked 1 and all equal to or below are marked as 0. This is called `binarizing` your data or
# `thresholding` your data.
#
# >
# - It can be useful when you have probabilities that you want to make crisp
# values.
# - It is also useful when feature engineering and you want to add new features that indicate
# something meaningful.

# %% [markdown]
# You can create new binary attributes in Python using
#
# `scikit-learn with the Binarizer`
#
# [What Binarize Does](#)
#
# > The binarize() function takes data in a "normal" format and converts to a binary format that is useful as a preparation step before using correlate():
#
# > Numeric Features: The "Normal Data" format has numeric features that are continuous values in numeric format (double or integer). The binarize() function converts these to bins (categories) and then discretizes the bins using a one-hot encoding process.
#
# > Categorical Features: The "Normal Data" format has categorical features that are character or factor format. The binarize() function converts these to binary features using a one-hot encoding process.

# %%
# binarization
from sklearn.preprocessing import Binarizer
array = dataframe.values
# separate array into input and output components
X = array[:,0:x]
Y = array[:,x]
binarizer = Binarizer(threshold=0.0).fit(X) 
# thresholdfloat, optional (0.0 by default) Feature values below or equal to this are replaced by 0, 
# above it by 1. Threshold may not be less than 0 for operations on sparse matrices.
binaryX = binarizer.transform(X)
# summarize transformed data
set_printoptions(precision=3)
print(binaryX[0:z,:]) # print sample
# precisionint or None, optional Number of digits of precision for floating point output (default 8). 
# May be None if floatmode is not fixed, to print as many digits as necessary to uniquely specify the value.

# %% [markdown]
# __________
# __________
# _________

# %% [markdown]
# ### **Outliers Handling**

# %% [markdown]
#
# > **Why!**
# 1.  Some individuals in the sample are extreme;
# 2.  The data are inappropriately scaled;
# 3.  Errors were made on data entry;
# 4.  Unanticipated complexities exist in the relationships among variables

# %% [markdown]
# > Methods to Detect Outliers:
# -    Extreme Value Analysis
# -    Z-score method
# - Standard Deviation
# - IQR
# -    Visualizing the data

# %% [markdown]
# #### [Extreme Value Analysis](#)
# > determine the statistical tails of the underlying distribution of the variable and find the values at the extreme end of the tails.

# %% [markdown]
# #### ---> In case of a **Gaussian (Normal) Distribution**, the outliers will lie outside the mean plus or minus 3 times the standard deviation of the variable.

# %%
from IPython.display import Image
Image(filename='F:\Careers\Machine Learning\Articls - photos - Cheatsheets\outliers.JPG',width=300)

# %% [markdown]
# #### **[Standard Deviation](#)**
# if you have any data point that is more than 3 times the standard deviation, then those points are very likely to be anomalous or outliers.

# %%
Image(filename='F:\Careers\Machine Learning\Articls - photos - Cheatsheets\sttd.JPG',width=500)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
#seed(1)
anomalies = []

# multiply and add by random numbers to get some real values
data = np.random.randn(50000)  * 20 + 20

# Function to Detection Outlier on one-dimentional datasets.
def find_anomalies(random_data):
    # Set upper and lower limit to 3 standard deviation
    random_data_std = std(random_data)
    random_data_mean = mean(random_data)
    anomaly_cut_off = random_data_std * 3
    
    lower_limit  = random_data_mean - anomaly_cut_off 
    upper_limit = random_data_mean + anomaly_cut_off
    print(lower_limit)
    # Generate outliers
    for outlier in random_data:
        if outlier > upper_limit or outlier < lower_limit:
            anomalies.append(outlier)
    return anomalies

find_anomalies(data)

# %% [markdown]
# #### ---> If the variable is **not normally distributed** (not a Gaussian distribution), a general approach is to calculate the quantiles and then the inter-quartile range

# %%
Image(filename='F:\Careers\Machine Learning\Articls - photos - Cheatsheets\outliers2.JPG',width=400)

# %% [markdown]
# - IQR (Inter quantiles range)= 75th quantile — 25th quantile
#
# An outlier will be in the following upper and lower boundaries:
#
# - Upper Boundary = 75th quantile +(IQR * 1.5)Lower Boundary = 25th quantile — (IQR * 1.5)
#
# Or for extreme cases:
#
# - Upper Boundary = 75th quantile +(IQR * 3)Lower Boundary = 25th quantile — (IQR * 3)

# %% [markdown]
# > Steps
# 1- First, let's calculate the Inter Quantile Range for our dataset,
#
# `IQR = data.annual_inc.quantile(0.75) - data.annual_inc.quantile(0.25)`
#
# > Using the IQR, we calculate the upper boundary using the formulas mentioned above,
#
# `upper_limit = data.annual_inc.quantile(0.75) + (IQR * 1.5)`
#
# `upper_limit_extreme = data.annual_inc.quantile(0.75) + (IQR * 3)`
#
# `upper_limit, upper_limit_extreme` # now we have two upper limits = 178000 , Normal and Extreem = 256000
#
# > Now, let’s see the ratio of data points above the upper limit & extreme upper limit. ie, the outliers.
#
# `total = np.float(data.shape[0])`
#
# `print('Total borrowers: {}'.format(data.annual_inc.shape[0]/total))`
#
# `print('Borrowers that earn > 178k: {}'.format(data[data.annual_inc>178000].shape[0]/total))`
#
# `print('Borrowers that earn > 256k: {}'.format(data[data.annual_inc>256000].shape[0]/total))`

# %%
Image(filename='F:\Careers\Machine Learning\Articls - photos - Cheatsheets\outliers3.JPG',width=600)

# %% [markdown]
# #### **[Using IQR](#)**  Second way
# #### Anything outside the lower bound and upper bound is outlier
# IQR tells how spread the middle values are. It can be used to tell when a value is too far from the middle.
#
# An outlier is a point which falls more than 1.5 times the interquartile range above the third quartile or below the first quartile.
#
# we will use the same dataset
#
# step 1:
#
# Arrange the data in increasing order
# Calculate first(q1) and third quartile(q3)
# Find interquartile range (q3-q1)
# Find lower bound q1*1.5
# Find upper bound q3*1.5
# Anything that lies outside of lower and upper bound is an outlier

# %%
# 1
sorted(dataset)
# 2
q1, q3= np.percentile(dataset,[25,75])
# 3
iqr = q3 - q1
# 4
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

# %% [markdown]
# #### **lower_bound is 6.5 and upper bound is 18.5, so anything outside of 6.5 and 18.5 is an outlier.**

# %% [markdown]
# ___________
# ####  **[Standard Score (Z Score)](#)**

# %% [markdown]
# ####  || .  The intuition behind the Z-score method of outlier detection is that, once we’ve centered and rescaled the data,
# #### anything that is too far from zero (the threshold is usually a Z-score of 3 or -3) should be considered an outlier.

# %% [markdown]
# > Code
#
# `from scipy import stats`
#
# `z = stats.zscore(data)`
#
# `print(z)`
#
# ___________________ then ..
#
# `threshold = 3`
#
# `print(np.where(z > 3))`

# %% [markdown]
# ____________
# ####  **[Visualize Data](#)**

# %% [markdown]
# - Box Plots

# %%
Image(filename='F:\Careers\Machine Learning\Articls - photos - Cheatsheets\BoxPlot.JPG',width=600)

# %% [markdown]
# - Histogram

# %%
Image(filename='F:\Careers\Machine Learning\Articls - photos - Cheatsheets\Hist.JPG',width=600)

# %% [markdown]
# - Scatter Plot

# %%
Image(filename='F:\Careers\Machine Learning\Articls - photos - Cheatsheets\Scatter.JPG',width=450)

# %% [markdown]
# #### **Methods to Pre-Process Outliers**
#
# Much of the debate on how to deal with outliers in data comes down to the following question: Should you keep outliers, remove them, or change them to another variable?
#
# Essentially, instead of removing outliers from the data, you change their values to something more representative of your data set. It’s a small but important distinction: When you trim data, the extreme values are discarded

# %% [markdown]
# >
# - Mean/Median or random Imputation :
# - Drop
# - Top, Bottom and Zero Coding
# - Discretization

# %% [markdown]
# ________________________

# %% [markdown]
# ### [Duplicate records](#)

# %% [markdown]
# > More than one record that is exactly the same. This is what I call "exact duplication".
#
# >More than one record associated with the same observation, but the values in the rows are not exactly the same. This is what I call "partial duplication", but removing these types of duplicated records is also called "record linkage".

# %% [markdown]
# #### You can use `pandas.DataFrame.drop_duplicates` to Find & Dropping Dublicated records at the same Time

# %% [markdown]
# `# drop duplicate rows
# df.drop_duplicates()`

# %% [markdown]
# `# drop duplicate rows
# df.drop_duplicates(keep='last')`

# %% [markdown]
# `# drop duplicate by a column name
# df.drop_duplicates(['Column_Name'], keep='last')`

# %% [markdown]
# _________________________

# %% [markdown]
# ### [Feature Selection NOT Dimensionality Reduction](#)
#
# **“Garbage Data In, Garbage Results Out”**

# %% [markdown]
# Methods of feature selection ..

# %% [markdown]
# > **[Filter Methods](#)** : statistical measure to assign a scoring of each attribute/ feature and selection is done according to the ranking of the feature. This methods are often univariate and consider feature independently. These methods are effective in computational time and robust to overfitting. But they tend to select redundant variables because they do not consider the relationship between features.
# - Chi-Squared Test
# - Information Gain
# - F Test
# - ANOVA
# - Correlation Coefficient Scores (eg. Pearson’s Correlation Coefficient)

# %% [markdown]
# > **[Wrapper Methods](#)** : Wrapper methods consider the selection of a set of features as a search problem.
# - Ex.Recursive Feature Elimination

# %% [markdown]
# > **[Embedded methods](#)** : combine the advantages of both Filter and Wrapper methods. It is implemented by the learning algorithms that have their own built-in feature selection methods. The most common type of embedded methods of feature selection methods is regularization methods.
# - Lasso Regression
# - Ridge Regression
# - Elastic Nets
# - Decision Trees

# %% [markdown]
# ####  **Best Practice** ..... For SuperVised Learning
# _____

# %% [markdown]
# #### 1- [Univariate Selection](#)
# - Statistical tests can be used to select those features that have the strongest relationship with the output variable.
# -  chi-squared (chi2) statistical test for non-negative features

# %%
# Feature Extraction with Univariate Statistical Tests (Chi-squared for classification)
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# load data
# Convert DataSet to array
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(X)
# summarize selected features
print(features[0:5,:])

# %% [markdown]
# #### 2- [Recursive Feature Elimination RFE](#)
# - First, the estimator is trained on the initial set of features and the importance of each feature is obtained either through a coef_ attribute or through a feature_importances_ attribute.
#
# - Then, the least important features are pruned from current set of features.

# %%
# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data
# Convert Data ..
array = dataframe.values
# Split Data
X = array[:,0:8]
Y = array[:,8]
# feature extraction
model = LogisticRegression()
rfe = RFE(model, 3)
fit = rfe.fit(X, Y)
print("Num Features: %d") % fit.n_features_
print("Selected Features: %s") % fit.support_
print("Feature Ranking: %s") % fit.ranking_

# %% [markdown]
# #### 3- [Principal component analysis (PCA)](#).
#
# Linear dimensionality reduction using Singular Value Decomposition of the data to project it to a lower dimensional space. The input data is centered but not scaled for each feature before applying the SVD.
#
# It uses the LAPACK implementation of the full SVD or a randomized truncated SVD by the method of Halko et al. 2009, depending on the shape of the input data and the number of components to extract.
#
# It can also use the scipy.sparse.linalg ARPACK implementation of the truncated SVD.
#
# **A property of PCA is that
# you can choose the number of dimensions or principal components in the transformed result**

# %%
# Feature Extraction with PCA
from sklearn.decomposition import PCA
# load data
# convert data
array = dataframe.values
# Split Data
X = array[:,0:x]
Y = array[:,x]
# feature extraction
pca = PCA(n_components=#!Number!)
fit = pca.fit(X)
# summarize components
print("Explained Variance: %s") % fit.explained_variance_ratio_
print(fit.components_)

# %% [markdown]
# #### 4- [Use Feature Importance](#)

# %% [markdown]
# Bagged decision trees like **Random Forest** and **Extra Trees** can be used to estimate the importance
# of features.

# %%
# Feature Importance with Extra Trees Classifier
from sklearn.ensemble import ExtraTreesClassifier
# load data
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
model = ExtraTreesClassifier()
model.fit(X, Y)
print(model.feature_importances_)
